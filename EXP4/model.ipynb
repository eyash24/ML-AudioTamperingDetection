# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import signal
import librosa
import os
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from pydub import AudioSegment
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
from torchinfo import summary
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import roc_curve, auc
from tqdm.notebook import tqdm

# %%
BATCH_SIZE = 16

DATASET_DIR = "/Users/eyash.p24/Desktop/MUJ/ML/ATD_ML/dataset/tampered_dataset_small_v2_wav"

# %%
def tamper_type(filename):
    file_split = filename[:-4].split("_")[-1]
    # print(file_split)
    return file_split

test_file ="Audio_01_00018_330s_to_360s_insert.mp3"
tamper_type(test_file)
# Out:
# 'insert'

# %%
def extract_features(file_path):
    signal, sr = librosa.load(file_path)
    mfccs = librosa.feature.mfcc(y=signal, n_mfcc=13, sr=sr)
    delta_mfccs = librosa.feature.delta(mfccs)
    delta2_mfccs = librosa.feature.delta(mfccs, order=2)

    return np.array([mfccs, delta_mfccs, delta2_mfccs])

# %%
features = []
labels = []

# Extract features from dataset
for filename in os.listdir(DATASET_DIR):
    if filename.endswith('.wav'):
        file_path = os.path.join(DATASET_DIR, filename)
        try:
            type_file = tamper_type(filename)
            # print(labels)
            feature = extract_features(file_path)
            features.append(feature)
            # print(filename)

            if type_file == "insert":
                labels.append(0)
            elif type_file == "del":
                labels.append(0)
            elif type_file == "replace":
                labels.append(0)
            else:
                labels.append(1)
        except:
            pass

len(features), len(labels), type(features)
# Out:
# (400, 400, list)

# %%
type(features[0])
# Out:
# numpy.ndarray

# %%
class ENFDataset(Dataset):
    """Dataset class for ENF features"""
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels
        
    def __len__(self):
        return len(self.features)
    
    def __getitem__(self, idx):
        feature = torch.FloatTensor(self.features[idx])
        label = torch.FloatTensor([self.labels[idx]])
        return feature, label

# %%
def prepare_dataloader(features, labels):
    X_train, X_test, y_train, y_test = train_test_split(
    features, labels, test_size=0.2, random_state=42
    )

    X_train, X_val, y_train, y_val = train_test_split(
        X_train, y_train, test_size=0.2, random_state=42
    )

    train_dataset = ENFDataset(X_train, y_train)
    val_dataset = ENFDataset(X_val, y_val)
    test_dataset = ENFDataset(X_test, y_test)

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

    return train_loader, val_loader, test_loader

# %%
features[0][0].shape, features[0][1].shape, features[0][2].shape
# Out:
# ((13, 431), (13, 431), (13, 431))

# %%
train_loader_1, val_loader_1, test_loader_1 = prepare_dataloader(features, labels)

# %%
for file_path in os.listdir(DATASET_DIR):
    file_path = os.path.join(DATASET_DIR, file_path)
    break

_, sr = librosa.load(file_path)
sr
# Out:
# 22050

# %%
fe = features[45]
fe_mfccs = fe[0]
fe_delta_mfccs = fe[1]
fe_delta2_mfccs = fe[2]
labels[45]
# Out:
# 1

# %%
fe_mfccs.shape, fe_delta_mfccs.shape, fe_delta2_mfccs.shape
# Out:
# ((13, 431), (13, 431), (13, 431))

# %%
# visualizing mfccs
fe_mfccs_npy = fe_mfccs

plt.figure(figsize=(10,5))
librosa.display.specshow(
    fe_mfccs_npy, x_axis="time", sr=sr
)
plt.colorbar(format="%+2f")
plt.show()

# %%
# visualizing delta mfccs
plt.figure(figsize=(10,5))
librosa.display.specshow(
    fe_delta_mfccs, x_axis="time", sr=sr
)
plt.colorbar(format="%+2f")
plt.show()

# %%
# visualizing delta 2 mfccs
plt.figure(figsize=(10,5))
librosa.display.specshow(
    fe_delta2_mfccs, x_axis="time", sr=sr
)
plt.colorbar(format="%+2f")
plt.show()

# %%
for fe, _ in train_loader_1:
    print(fe.shape)
    break
# Out:
# torch.Size([16, 3, 13, 431])

# %% [markdown]
# ## Model

# %%
class CNNNetwork(nn.Module):
    def __init__(self):
        super(CNNNetwork, self).__init__()
        self.c1 =  nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(16),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(16, 16, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(16),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(512, 1, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(1),
            nn.ReLU(inplace=True),
        )
        self.f1 = nn.Flatten()
        self.d1 = nn.Sequential(
            nn.Linear(7,36),
             nn.Linear(36,36),
            nn.Linear(36,1),
        )
        self.o1 = nn.Sigmoid()
    
    def forward(self, x):
        x1 =  self.c1(x)
        x2 = self.f1(x1)
        x3 = self.d1(x2)
        x4 = self.o1(x3)

        return x4

# %%
model = CNNNetwork()
x = torch.randn(4, 3, 13, 431)
out = model(x)
out.shape, out
# Out:
# (torch.Size([4, 1]),
#  tensor([[0.4578],
#          [0.5133],
#          [0.4806],
#          [0.4285]], grad_fn=<SigmoidBackward0>))

# %%
summary(model=model, input=(1,3,13,431))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# CNNNetwork                               --
# ├─Sequential: 1-1                        --
# │    └─Conv2d: 2-1                       432
# │    └─BatchNorm2d: 2-2                  32
# │    └─ReLU: 2-3                         --
# │    └─Conv2d: 2-4                       4,096
# │    └─BatchNorm2d: 2-5                  32
# │    └─ReLU: 2-6                         --
# │    └─Conv2d: 2-7                       8,192
# │    └─BatchNorm2d: 2-8                  64
# │    └─ReLU: 2-9                         --
# │    └─Conv2d: 2-10                      18,432
# │    └─BatchNorm2d: 2-11                 128
# │    └─ReLU: 2-12                        --
# │    └─Conv2d: 2-13                      73,728
# │    └─BatchNorm2d: 2-14                 256
# │    └─ReLU: 2-15                        --
# │    └─Conv2d: 2-16                      294,912
# │    └─BatchNorm2d: 2-17                 512
# │    └─ReLU: 2-18                        --
# │    └─Conv2d: 2-19                      1,179,648
# │    └─BatchNorm2d: 2-20                 1,024
# │    └─ReLU: 2-21                        --
# │    └─Conv2d: 2-22                      2,359,296
# │    └─BatchNorm2d: 2-23                 1,024
# │    └─ReLU: 2-24                        --
# │    └─Conv2d: 2-25                      4,608
# │    └─BatchNorm2d: 2-26                 2
# │    └─ReLU: 2-27                        --
# ├─Flatten: 1-2                           --
# ├─Sequential: 1-3                        --
# │    └─Linear: 2-28                      288
# │    └─Linear: 2-29                      1,332
# │    └─Linear: 2-30                      37
# ├─Sigmoid: 1-4                           --
# =================================================================
# Total params: 3,948,075
# Trainable params: 3,948,075
# Non-trainable params: 0
# =================================================================

# %%
import torch.optim as optim
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# %%
import csv
# loss_g: 3.5279, loss_d: 0.6153, real_score: 0.7169, fake_score: 0.1814
titles = ["epoch", "train_accuracy", "train_loss", "val_loss", "val_accuracy"]

with open("record1.csv", 'w') as cf:
    csvwriter = csv.writer(cf)
    # writing the fields
    csvwriter.writerow(titles)
    # writing the data rows
cf.close()

# %%
def record_data(data, file='record1.csv'):

    with open(file, 'a') as cf:
        writer_object = csv.writer(cf)
        writer_object.writerow(data)
 
    # Close the file object
    cf.close()

# %%
def train_model(model, train_loader, val_loader, epochs=50, lr=0.001, file="record1.csv", model_path="trained_model1.pth"):
    """Train the CNN model"""
    # device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    device = "cpu"
    model = model.to(device)
    
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_model = None
    train_losses = []
    val_losses = []
    val_accs = []
    train_accs = []
    
    for epoch in range(epochs):
        # Training
        model.train()
        train_loss = 0.0
        correct_train = 0

        for features, labels in train_loader_1:
            # features, labels = features.to(device), labels.to(device)
            
            optimizer.zero_grad()
            # features = features.reshape([features.shape[0], 1, features.shape[1]])
            outputs = model(features)
            loss = criterion(outputs, labels)

            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * features.size(0)
            preds_train = (outputs > 0.5).float()
            correct_train += (preds_train == labels).sum().item()

        train_loss /= len(train_loader_1.dataset)
        train_acc = correct_train / len(train_loader_1.dataset)
        
        # Validation
        model.eval()
        val_loss = 0.0
        correct = 0
        
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                # inputs = inputs.reshape([inputs.shape[0], 1, inputs.shape[1]])
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                
                val_loss += loss.item() * inputs.size(0)
                
                preds = (outputs > 0.5).float()
                correct += (preds == labels).sum().item()
        
        val_loss /= len(val_loader.dataset)
        val_acc = correct / len(val_loader.dataset)
        
        print(f'Epoch {epoch+1}/{epochs},Train Acc: {train_acc:.4f}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')

        record_data([epoch+1, train_acc, train_loss, val_loss, val_acc], file=file)
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        val_accs.append(val_acc)
        train_accs.append(train_acc)
        
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = model.state_dict().copy()
    
    # Load best model
    model.load_state_dict(best_model)

    # Save the model
    torch.save(model.state_dict(),model_path)
        

    return (train_accs, train_losses, val_losses, val_accs)

# %%
epochs = 50
lr = 0.001

# %%
# Model Training
history1 = train_model(model, train_loader_1, val_loader_1, epochs=epochs, lr=lr, file="record1.csv", model_path='trained_model1.pth')
print("Done")
# Out:
# Epoch 1/50,Train Acc: 0.4961, Train Loss: 0.6560, Val Loss: 0.6941, Val Acc: 0.4844
# Epoch 2/50,Train Acc: 0.6523, Train Loss: 0.5436, Val Loss: 0.5600, Val Acc: 0.8594
# Epoch 3/50,Train Acc: 0.9141, Train Loss: 0.4240, Val Loss: 0.6335, Val Acc: 0.6719
# Epoch 4/50,Train Acc: 0.9414, Train Loss: 0.3141, Val Loss: 0.2503, Val Acc: 0.9375
# Epoch 5/50,Train Acc: 0.9492, Train Loss: 0.2238, Val Loss: 0.3987, Val Acc: 0.8125
# Epoch 6/50,Train Acc: 0.9648, Train Loss: 0.1564, Val Loss: 0.2454, Val Acc: 0.9375
# Epoch 7/50,Train Acc: 0.9609, Train Loss: 0.1347, Val Loss: 0.5016, Val Acc: 0.7656
# Epoch 8/50,Train Acc: 0.9414, Train Loss: 0.1331, Val Loss: 0.3236, Val Acc: 0.8906
# Epoch 9/50,Train Acc: 0.9805, Train Loss: 0.0640, Val Loss: 0.2172, Val Acc: 0.9062
# Epoch 10/50,Train Acc: 0.9805, Train Loss: 0.0670, Val Loss: 0.4172, Val Acc: 0.8438
# Epoch 11/50,Train Acc: 0.9922, Train Loss: 0.0348, Val Loss: 0.1749, Val Acc: 0.9531
# Epoch 12/50,Train Acc: 0.9648, Train Loss: 0.0838, Val Loss: 0.1493, Val Acc: 0.9375
# Epoch 13/50,Train Acc: 0.9531, Train Loss: 0.0897, Val Loss: 0.1845, Val Acc: 0.9531
# Epoch 14/50,Train Acc: 0.9922, Train Loss: 0.0352, Val Loss: 0.3156, Val Acc: 0.9062
# Epoch 15/50,Train Acc: 0.9844, Train Loss: 0.0412, Val Loss: 0.3306, Val Acc: 0.8438
# Epoch 16/50,Train Acc: 0.9844, Train Loss: 0.0375, Val Loss: 0.3510, Val Acc: 0.8906
# Epoch 17/50,Train Acc: 0.9883, Train Loss: 0.0461, Val Loss: 0.1699, Val Acc: 0.9375
# Epoch 18/50,Train Acc: 0.9961, Train Loss: 0.0139, Val Loss: 0.0903, Val Acc: 0.9688
# Epoch 19/50,Train Acc: 1.0000, Train Loss: 0.0101, Val Loss: 0.1807, Val Acc: 0.9375
# Epoch 20/50,Train Acc: 1.0000, Train Loss: 0.0084, Val Loss: 0.1772, Val Acc: 0.9375
# Epoch 21/50,Train Acc: 1.0000, Train Loss: 0.0057, Val Loss: 0.1264, Val Acc: 0.9531
# Epoch 22/50,Train Acc: 1.0000, Train Loss: 0.0087, Val Loss: 0.1653, Val Acc: 0.9688
# Epoch 23/50,Train Acc: 1.0000, Train Loss: 0.0064, Val Loss: 0.1081, Val Acc: 0.9688
# Epoch 24/50,Train Acc: 1.0000, Train Loss: 0.0027, Val Loss: 0.0958, Val Acc: 0.9844
# Epoch 25/50,Train Acc: 1.0000, Train Loss: 0.0019, Val Loss: 0.1080, Val Acc: 0.9688
# Epoch 26/50,Train Acc: 1.0000, Train Loss: 0.0042, Val Loss: 0.2706, Val Acc: 0.8906
# Epoch 27/50,Train Acc: 0.9922, Train Loss: 0.0277, Val Loss: 0.2936, Val Acc: 0.8906
# Epoch 28/50,Train Acc: 0.9844, Train Loss: 0.0342, Val Loss: 0.4867, Val Acc: 0.8750
# Epoch 29/50,Train Acc: 0.9531, Train Loss: 0.1283, Val Loss: 1.4900, Val Acc: 0.7656
# Epoch 30/50,Train Acc: 0.9414, Train Loss: 0.1779, Val Loss: 1.6722, Val Acc: 0.7969
# Epoch 31/50,Train Acc: 0.9609, Train Loss: 0.1509, Val Loss: 0.1202, Val Acc: 0.9531
# Epoch 32/50,Train Acc: 0.9805, Train Loss: 0.0515, Val Loss: 0.1973, Val Acc: 0.9219
# Epoch 33/50,Train Acc: 0.9805, Train Loss: 0.0441, Val Loss: 0.3153, Val Acc: 0.8906
# Epoch 34/50,Train Acc: 0.9922, Train Loss: 0.0203, Val Loss: 0.1506, Val Acc: 0.9375
# Epoch 35/50,Train Acc: 0.9961, Train Loss: 0.0201, Val Loss: 0.1223, Val Acc: 0.9375
# Epoch 36/50,Train Acc: 1.0000, Train Loss: 0.0059, Val Loss: 0.1977, Val Acc: 0.9375
# Epoch 37/50,Train Acc: 0.9883, Train Loss: 0.0312, Val Loss: 0.5457, Val Acc: 0.8281
# Epoch 38/50,Train Acc: 0.9844, Train Loss: 0.0656, Val Loss: 0.3336, Val Acc: 0.8750
# Epoch 39/50,Train Acc: 0.9922, Train Loss: 0.0177, Val Loss: 0.3268, Val Acc: 0.9375
# Epoch 40/50,Train Acc: 0.9961, Train Loss: 0.0107, Val Loss: 0.1867, Val Acc: 0.9531
# Epoch 41/50,Train Acc: 1.0000, Train Loss: 0.0064, Val Loss: 0.1606, Val Acc: 0.9531
# Epoch 42/50,Train Acc: 0.9922, Train Loss: 0.0182, Val Loss: 0.1468, Val Acc: 0.9375
# Epoch 43/50,Train Acc: 1.0000, Train Loss: 0.0057, Val Loss: 0.2369, Val Acc: 0.9219
# Epoch 44/50,Train Acc: 1.0000, Train Loss: 0.0057, Val Loss: 0.1886, Val Acc: 0.9531
# Epoch 45/50,Train Acc: 1.0000, Train Loss: 0.0023, Val Loss: 0.1885, Val Acc: 0.9375
# Epoch 46/50,Train Acc: 1.0000, Train Loss: 0.0013, Val Loss: 0.2036, Val Acc: 0.9375
# Epoch 47/50,Train Acc: 1.0000, Train Loss: 0.0015, Val Loss: 0.2052, Val Acc: 0.9375
# Epoch 48/50,Train Acc: 1.0000, Train Loss: 0.0011, Val Loss: 0.2034, Val Acc: 0.9219
# Epoch 49/50,Train Acc: 1.0000, Train Loss: 0.0032, Val Loss: 0.2193, Val Acc: 0.9375
# Epoch 50/50,Train Acc: 1.0000, Train Loss: 0.0009, Val Loss: 0.2204, Val Acc: 0.9375
# Done

# %%
torch.save(model.state_dict(),"final_model1.pth")

# %%
train_accuracy, training_losses, val_losses, val_accuracy = history1

# %%
len(train_accuracy), len(training_losses), len(val_losses), len(val_accuracy)
# Out:
# (50, 50, 50, 50)

# %%
# Plot Generator and Discriminator Loss
plt.plot(training_losses, '-')
plt.plot(val_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(["training_losses", "val_losses"])
plt.title('Model Losses')
# Out:
# Text(0.5, 1.0, 'Model Losses')

# %%
# Plot Real and Fake score
plt.plot(train_accuracy, '-')
plt.plot(val_accuracy, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Train Accuracy', "Val Accuracy"])
plt.title('Scores')
plt.show()

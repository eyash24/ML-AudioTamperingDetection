# %% [markdown]
# <a href="https://colab.research.google.com/github/eyash24/ML-AudioTamperingDetection/blob/main/yt_downlaod.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Audio Tampering Detection Dataset

# %% [markdown]
# Downloading youtube playlist as dataset for audio tampering detection
# <br>
# using google drive for storing audio

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install yt-dlp
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.2/172.2 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 44.1 MB/s eta 0:00:00
# ...

# %%
ytLink = "https://youtube.com/playlist?list=PLI5ThqEVT0-YW14NerJOXygeakO5zovEm&si=0HNWms2SrhzYmq7C"

# %%
import yt_dlp
import os

# %%
def download_playlist_audio(playlist_url, output_path='downloads'):
    """
    Download audio files from a YouTube playlist.

    :param playlist_url: URL of the YouTube playlist
    :param output_path: Directory to save downloaded audio files
    """
    # Create output directory if it doesn't exist
    os.makedirs(output_path, exist_ok=True)

    # Configuration for yt-dlp
    ydl_opts = {
        'format': 'bestaudio/best',  # Best audio quality
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',  # Extract audio
            'preferredcodec': 'mp3',  # Convert to MP3
            'preferredquality': '192',  # 192 kbps quality
        }],
        'outtmpl': os.path.join(output_path, '%(title)s.%(ext)s'),  # Output template
        'nooverwrites': True,  # Don't overwrite existing files
        'no_color': True,  # Disable color output
        'no_warnings': True,  # Suppress warnings
    }

    # Download playlist
    try:
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download([playlist_url])
        print(f"Successfully downloaded playlist from: {playlist_url}")
    except Exception as e:
        print(f"Error downloading playlist: {e}")

def main():
    # Get playlist URL from user
    playlist_url = ytLink

    # Optional: Specify custom download path
    output_path = "/content/drive/MyDrive/yt-video"

    # Download playlist
    download_playlist_audio(playlist_url, output_path)

if __name__ == '__main__':
    main()
# Out:
# [youtube:tab] Extracting URL: https://youtube.com/playlist?list=PLI5ThqEVT0-YW14NerJOXygeakO5zovEm&si=0HNWms2SrhzYmq7C
# [youtube:tab] PLI5ThqEVT0-YW14NerJOXygeakO5zovEm: Downloading webpage
# [youtube:tab] PLI5ThqEVT0-YW14NerJOXygeakO5zovEm: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: ml audio tampering dataset
# [youtube:tab] PLI5ThqEVT0-YW14NerJOXygeakO5zovEm page 1: Downloading API JSON
# [youtube:tab] PLI5ThqEVT0-YW14NerJOXygeakO5zovEm page 2: Downloading API JSON
# [youtube:tab] Playlist ml audio tampering dataset: Downloading 256 items of 256
# [download] Downloading item 1 of 256
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8ocdH2nhFuI
# [youtube] 8ocdH2nhFuI: Downloading webpage
# [youtube] 8ocdH2nhFuI: Downloading tv player API JSON
# [youtube] 8ocdH2nhFuI: Downloading ios player API JSON
# [youtube] 8ocdH2nhFuI: Downloading player dd017f77
# [youtube] 8ocdH2nhFuI: Downloading m3u8 information
# ...

# %%
# !ls /content/drive/MyDrive/yt-video >> logs.txt

# %%
with open("/content/logs.txt", "r") as myfile:
  content = myfile.readlines()

# %%
print(len(content))
# Out:
# 221

# %%
myfile.close()

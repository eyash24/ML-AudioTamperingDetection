# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import signal
import librosa
import os
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from pydub import AudioSegment
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
from torchinfo import summary
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import roc_curve, auc
from tqdm.notebook import tqdm

# %%
BATCH_SIZE = 16

DATASET_DIR = "/Users/eyash.p24/Desktop/MUJ/ML/ATD_ML/dataset/tampered_dataset_small_wav"

# %%
def tamper_type(filename):
    file_split = filename[:-4].split("_")[-1]
    # print(file_split)
    return file_split

test_file ="Audio_01_00018_330s_to_360s_insert.mp3"
tamper_type(test_file)
# Out:
# 'insert'

# %%
def extract_features(file_path):
    signal, sr = librosa.load(file_path)
    mfccs = librosa.feature.mfcc(y=signal, n_mfcc=13, sr=sr)
    delta_mfccs = librosa.feature.delta(mfccs)
    delta2_mfccs = librosa.feature.delta(mfccs, order=2)

    return np.array([mfccs, delta_mfccs, delta2_mfccs])

# %%
features = []
labels = []

# Extract features from dataset
for filename in os.listdir(DATASET_DIR):
    if filename.endswith('.wav'):
        file_path = os.path.join(DATASET_DIR, filename)
        try:
            type_file = tamper_type(filename)
            # print(labels)
            feature = extract_features(file_path)
            features.append(feature)
            # print(filename)

            if type_file == "insert":
                labels.append(0)
            elif type_file == "del":
                labels.append(1)
            elif type_file == "replace":
                labels.append(2)
            else:
                labels.append(3)
        except:
            pass

len(features), len(labels), type(features)
# Out:
# (800, 800, list)

# %%
type(features[0])
# Out:
# numpy.ndarray

# %%
class ENFDataset(Dataset):
    """Dataset class for ENF features"""
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels
        
    def __len__(self):
        return len(self.features)
    
    def __getitem__(self, idx):
        feature = torch.FloatTensor(self.features[idx])
        label = torch.FloatTensor([self.labels[idx]])
        return feature, label

# %%
def prepare_dataloader(features, labels):
    X_train, X_test, y_train, y_test = train_test_split(
    features, labels, test_size=0.2, random_state=42
    )

    X_train, X_val, y_train, y_val = train_test_split(
        X_train, y_train, test_size=0.2, random_state=42
    )

    train_dataset = ENFDataset(X_train, y_train)
    val_dataset = ENFDataset(X_val, y_val)
    test_dataset = ENFDataset(X_test, y_test)

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

    return train_loader, val_loader, test_loader, X_test, y_test

# %%
features[0][0].shape, features[0][1].shape, features[0][2].shape
# Out:
# ((13, 431), (13, 431), (13, 431))

# %%
train_loader_1, val_loader_1, test_loader_1, X_test, y_test = prepare_dataloader(features, labels)

# %%
len(X_test), len(y_test)
# Out:
# (160, 160)

# %%
for file_path in os.listdir(DATASET_DIR):
    file_path = os.path.join(DATASET_DIR, file_path)
    break

_, sr = librosa.load(file_path)
sr
# Out:
# 22050

# %%
fe = features[45]
fe_mfccs = fe[0]
fe_delta_mfccs = fe[1]
fe_delta2_mfccs = fe[2]
labels[45]
# Out:
# 3

# %%
fe_mfccs.shape, fe_delta_mfccs.shape, fe_delta2_mfccs.shape
# Out:
# ((13, 431), (13, 431), (13, 431))

# %%
# visualizing mfccs
fe_mfccs_npy = fe_mfccs

plt.figure(figsize=(10,5))
librosa.display.specshow(
    fe_mfccs_npy, x_axis="time", sr=sr
)
plt.colorbar(format="%+2f")
plt.show()

# %%
# visualizing delta mfccs
plt.figure(figsize=(10,5))
librosa.display.specshow(
    fe_delta_mfccs, x_axis="time", sr=sr
)
plt.colorbar(format="%+2f")
plt.show()

# %%
# visualizing delta 2 mfccs
plt.figure(figsize=(10,5))
librosa.display.specshow(
    fe_delta2_mfccs, x_axis="time", sr=sr
)
plt.colorbar(format="%+2f")
plt.show()

# %%
for fe, _ in train_loader_1:
    print(fe.shape)
    break
# Out:
# torch.Size([16, 3, 13, 431])

# %% [markdown]
# ## Model

# %%
class CNNNetwork(nn.Module):
    def __init__(self):
        super(CNNNetwork, self).__init__()
        self.c1 =  nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(16),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(16, 16, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(16),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(512, 1, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(1),
            nn.ReLU(inplace=True),
        )
        self.f1 = nn.Flatten()
        self.d1 = nn.Sequential(
            nn.Linear(7,36),
             nn.Linear(36,36),
            nn.Linear(36,4),
        )
        # self.o1 = nn.Softmax()
    
    def forward(self, x):
        x1 =  self.c1(x)
        x2 = self.f1(x1)
        x3 = self.d1(x2)
        # x4 = self.o1(x3)

        return x3

# %%
model = CNNNetwork()
x = torch.randn(4, 3, 13, 431)
out = model(x)
out.shape, out
# Out:
# (torch.Size([4, 4]),
#  tensor([[ 0.0636, -0.0252,  0.1126, -0.0620],
#          [ 0.1427, -0.1876,  0.0832, -0.1364],
#          [ 0.4632, -0.3312,  0.1640, -0.1774],
#          [ 0.2321,  0.0762,  0.0526,  0.0405]], grad_fn=<AddmmBackward0>))

# %%
summary(model=model, input=(1,3,13,431))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# CNNNetwork                               --
# ├─Sequential: 1-1                        --
# │    └─Conv2d: 2-1                       432
# │    └─BatchNorm2d: 2-2                  32
# │    └─ReLU: 2-3                         --
# │    └─Conv2d: 2-4                       4,096
# │    └─BatchNorm2d: 2-5                  32
# │    └─ReLU: 2-6                         --
# │    └─Conv2d: 2-7                       8,192
# │    └─BatchNorm2d: 2-8                  64
# │    └─ReLU: 2-9                         --
# │    └─Conv2d: 2-10                      18,432
# │    └─BatchNorm2d: 2-11                 128
# │    └─ReLU: 2-12                        --
# │    └─Conv2d: 2-13                      73,728
# │    └─BatchNorm2d: 2-14                 256
# │    └─ReLU: 2-15                        --
# │    └─Conv2d: 2-16                      294,912
# │    └─BatchNorm2d: 2-17                 512
# │    └─ReLU: 2-18                        --
# │    └─Conv2d: 2-19                      1,179,648
# │    └─BatchNorm2d: 2-20                 1,024
# │    └─ReLU: 2-21                        --
# │    └─Conv2d: 2-22                      2,359,296
# │    └─BatchNorm2d: 2-23                 1,024
# │    └─ReLU: 2-24                        --
# │    └─Conv2d: 2-25                      4,608
# │    └─BatchNorm2d: 2-26                 2
# │    └─ReLU: 2-27                        --
# ├─Flatten: 1-2                           --
# ├─Sequential: 1-3                        --
# │    └─Linear: 2-28                      288
# │    └─Linear: 2-29                      1,332
# │    └─Linear: 2-30                      148
# =================================================================
# Total params: 3,948,186
# Trainable params: 3,948,186
# Non-trainable params: 0
# =================================================================

# %%
import torch.optim as optim
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
import csv
# loss_g: 3.5279, loss_d: 0.6153, real_score: 0.7169, fake_score: 0.1814
titles = ["epoch", "train_accuracy", "train_loss", "val_loss", "val_accuracy"]

with open("record1.csv", 'w') as cf:
    csvwriter = csv.writer(cf)
    # writing the fields
    csvwriter.writerow(titles)
    # writing the data rows
cf.close()

# %%
def record_data(data, file='record1.csv'):

    with open(file, 'a') as cf:
        writer_object = csv.writer(cf)
        writer_object.writerow(data)
 
    # Close the file object
    cf.close()

# %%
# def train_model(model, train_loader, val_loader, epochs=50, lr=0.001, file="record1.csv", model_path="trained_model1.pth"):
#     """Train the CNN model"""
#     # device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#     device = "cpu"
#     model = model.to(device)
    
#     # criterion = nn.BCELoss()
#     # optimizer = optim.Adam(model.parameters(), lr=lr)
    
#     best_val_loss = float('inf')
#     best_model = None
#     train_losses = []
#     val_losses = []
#     val_accs = []
#     train_accs = []
    
#     for epoch in range(epochs):
#         # Training
#         model.train()
#         train_loss = 0.0
#         correct_train = 0

#         for features, labels in train_loader_1:
            
#             optimizer.zero_grad()
#             outputs = model(features)
#             loss = criterion(outputs, labels)

#             loss.backward()
#             optimizer.step()
            
#             train_loss += loss.item() * features.size(0)
#             preds_train = (outputs > 0.5).float()
#             correct_train += (preds_train == labels).sum().item()

#         train_loss /= len(train_loader_1.dataset)
#         train_acc = correct_train / len(train_loader_1.dataset)
        
#         # Validation
#         model.eval()
#         val_loss = 0.0
#         correct = 0
        
#         with torch.no_grad():
#             for inputs, labels in val_loader:
#                 inputs, labels = inputs.to(device), labels.to(device)
#                 # inputs = inputs.reshape([inputs.shape[0], 1, inputs.shape[1]])
#                 outputs = model(inputs)
#                 loss = criterion(outputs, labels)
                
#                 val_loss += loss.item() * inputs.size(0)
                
#                 preds = (outputs > 0.5).float()
#                 correct += (preds == labels).sum().item()
        
#         val_loss /= len(val_loader.dataset)
#         val_acc = correct / len(val_loader.dataset)
        
#         print(f'Epoch {epoch+1}/{epochs},Train Acc: {train_acc:.4f}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')

#         record_data([epoch+1, train_acc, train_loss, val_loss, val_acc], file=file)
#         train_losses.append(train_loss)
#         val_losses.append(val_loss)
#         val_accs.append(val_acc)
#         train_accs.append(train_acc)
        
#         if val_loss < best_val_loss:
#             best_val_loss = val_loss
#             best_model = model.state_dict().copy()
    
#     # Load best model
#     model.load_state_dict(best_model)

#     # Save the model
#     torch.save(model.state_dict(),model_path)
        

#     return (train_accs, train_losses, val_losses, val_accs)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

def train_model_multiclass(model, train_loader, val_loader, epochs=50, lr=0.001, file="record1.csv", model_path="trained_model1.pth", momentum=0.85):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    
    criterion = nn.CrossEntropyLoss()  # Multiclass classification loss
    # optimizer = optim.Adam(model.parameters(), lr=lr)
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
    
    best_val_loss = float('inf')
    best_model = None
    train_losses, val_losses = [], []
    train_accs, val_accs = [], []

    for epoch in range(epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        correct_train = 0

        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)  # Move to GPU/CPU

            optimizer.zero_grad()
            outputs = model(features)  # Logits: [batch_size, num_classes]
            
            # Ensure labels are of type `long` and shape `[batch_size]`
            labels = labels.squeeze().long()
            
            loss = criterion(outputs, labels)  # CrossEntropyLoss expects raw logits and class indices
            
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * features.size(0)
            preds_train = torch.argmax(outputs, dim=1)  # Get predicted class indices
            correct_train += (preds_train == labels).sum().item()

        train_loss /= len(train_loader.dataset)
        train_acc = correct_train / len(train_loader.dataset)

        # Validation phase
        model.eval()
        val_loss = 0.0
        correct = 0
        
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = model(inputs)
                labels = labels.squeeze().long()  # Ensure proper label shape
                
                loss = criterion(outputs, labels)
                
                val_loss += loss.item() * inputs.size(0)
                preds = torch.argmax(outputs, dim=1)  # Get predicted class indices
                correct += (preds == labels).sum().item()
        
        val_loss /= len(val_loader.dataset)
        val_acc = correct / len(val_loader.dataset)

        print(f'Epoch {epoch+1}, Train Acc: {train_acc:.4f}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')
        record_data([epoch+1, train_acc, train_loss, val_loss, val_acc], file=file)
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accs.append(train_acc)
        val_accs.append(val_acc)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = model.state_dict().copy()
    
    # Load best model
    model.load_state_dict(best_model)

    # Save the model
    torch.save(model.state_dict(), model_path)

    return train_accs, train_losses, val_losses, val_accs

# %%
epochs = 100
lr = 0.001

# %%
# Model Training
history1 = train_model_multiclass(model, train_loader_1, val_loader_1, epochs=epochs, lr=lr, file="record1.csv", model_path='trained_model1.pth')
print("Done")
# Out:
# Epoch 1, Train Acc: 0.2266, Train Loss: 1.3778, Val Loss: 1.3888, Val Acc: 0.2891
# Epoch 2, Train Acc: 0.4121, Train Loss: 1.2835, Val Loss: 1.2375, Val Acc: 0.5234
# Epoch 3, Train Acc: 0.5859, Train Loss: 1.1606, Val Loss: 1.1385, Val Acc: 0.5312
# Epoch 4, Train Acc: 0.6777, Train Loss: 1.0467, Val Loss: 1.0601, Val Acc: 0.5938
# Epoch 5, Train Acc: 0.8164, Train Loss: 0.9214, Val Loss: 1.0463, Val Acc: 0.5938
# Epoch 6, Train Acc: 0.9062, Train Loss: 0.7957, Val Loss: 0.9904, Val Acc: 0.6094
# Epoch 7, Train Acc: 0.9570, Train Loss: 0.6446, Val Loss: 1.0072, Val Acc: 0.5703
# Epoch 8, Train Acc: 0.9805, Train Loss: 0.4881, Val Loss: 1.0219, Val Acc: 0.5703
# Epoch 9, Train Acc: 0.9824, Train Loss: 0.3429, Val Loss: 1.0352, Val Acc: 0.5391
# Epoch 10, Train Acc: 0.9961, Train Loss: 0.2046, Val Loss: 1.0137, Val Acc: 0.5391
# Epoch 11, Train Acc: 0.9961, Train Loss: 0.1362, Val Loss: 0.9180, Val Acc: 0.6328
# Epoch 12, Train Acc: 0.9980, Train Loss: 0.0819, Val Loss: 0.9276, Val Acc: 0.6406
# Epoch 13, Train Acc: 0.9980, Train Loss: 0.0647, Val Loss: 0.9956, Val Acc: 0.6172
# Epoch 14, Train Acc: 0.9980, Train Loss: 0.0489, Val Loss: 0.9485, Val Acc: 0.6484
# Epoch 15, Train Acc: 1.0000, Train Loss: 0.0352, Val Loss: 0.9644, Val Acc: 0.5938
# Epoch 16, Train Acc: 1.0000, Train Loss: 0.0242, Val Loss: 0.9134, Val Acc: 0.6172
# Epoch 17, Train Acc: 1.0000, Train Loss: 0.0208, Val Loss: 0.9893, Val Acc: 0.6016
# Epoch 18, Train Acc: 1.0000, Train Loss: 0.0205, Val Loss: 0.9469, Val Acc: 0.6250
# Epoch 19, Train Acc: 1.0000, Train Loss: 0.0172, Val Loss: 0.9649, Val Acc: 0.6250
# Epoch 20, Train Acc: 1.0000, Train Loss: 0.0139, Val Loss: 0.9573, Val Acc: 0.6406
# Epoch 21, Train Acc: 1.0000, Train Loss: 0.0113, Val Loss: 0.9603, Val Acc: 0.6406
# Epoch 22, Train Acc: 0.9980, Train Loss: 0.0132, Val Loss: 0.9459, Val Acc: 0.6562
# Epoch 23, Train Acc: 1.0000, Train Loss: 0.0117, Val Loss: 0.9837, Val Acc: 0.6328
# Epoch 24, Train Acc: 1.0000, Train Loss: 0.0103, Val Loss: 0.9842, Val Acc: 0.6328
# Epoch 25, Train Acc: 1.0000, Train Loss: 0.0081, Val Loss: 0.9803, Val Acc: 0.6250
# Epoch 26, Train Acc: 1.0000, Train Loss: 0.0078, Val Loss: 0.9842, Val Acc: 0.6328
# Epoch 27, Train Acc: 1.0000, Train Loss: 0.0068, Val Loss: 0.9807, Val Acc: 0.6172
# Epoch 28, Train Acc: 1.0000, Train Loss: 0.0066, Val Loss: 0.9810, Val Acc: 0.6328
# Epoch 29, Train Acc: 1.0000, Train Loss: 0.0058, Val Loss: 0.9813, Val Acc: 0.6016
# Epoch 30, Train Acc: 1.0000, Train Loss: 0.0054, Val Loss: 0.9828, Val Acc: 0.6250
# Epoch 31, Train Acc: 1.0000, Train Loss: 0.0052, Val Loss: 0.9763, Val Acc: 0.6172
# Epoch 32, Train Acc: 1.0000, Train Loss: 0.0048, Val Loss: 0.9752, Val Acc: 0.6250
# Epoch 33, Train Acc: 1.0000, Train Loss: 0.0046, Val Loss: 0.9856, Val Acc: 0.6328
# Epoch 34, Train Acc: 1.0000, Train Loss: 0.0046, Val Loss: 0.9762, Val Acc: 0.6406
# Epoch 35, Train Acc: 1.0000, Train Loss: 0.0041, Val Loss: 0.9833, Val Acc: 0.6250
# Epoch 36, Train Acc: 1.0000, Train Loss: 0.0049, Val Loss: 1.0028, Val Acc: 0.6250
# Epoch 37, Train Acc: 1.0000, Train Loss: 0.0039, Val Loss: 0.9883, Val Acc: 0.6172
# Epoch 38, Train Acc: 1.0000, Train Loss: 0.0038, Val Loss: 0.9842, Val Acc: 0.6562
# Epoch 39, Train Acc: 1.0000, Train Loss: 0.0036, Val Loss: 0.9785, Val Acc: 0.6484
# Epoch 40, Train Acc: 1.0000, Train Loss: 0.0034, Val Loss: 0.9864, Val Acc: 0.6328
# Epoch 41, Train Acc: 1.0000, Train Loss: 0.0034, Val Loss: 0.9978, Val Acc: 0.6250
# Epoch 42, Train Acc: 1.0000, Train Loss: 0.0031, Val Loss: 0.9984, Val Acc: 0.6250
# Epoch 43, Train Acc: 1.0000, Train Loss: 0.0031, Val Loss: 1.0041, Val Acc: 0.6172
# Epoch 44, Train Acc: 1.0000, Train Loss: 0.0029, Val Loss: 1.0028, Val Acc: 0.6328
# Epoch 45, Train Acc: 1.0000, Train Loss: 0.0029, Val Loss: 0.9985, Val Acc: 0.6328
# Epoch 46, Train Acc: 1.0000, Train Loss: 0.0026, Val Loss: 1.0013, Val Acc: 0.6328
# Epoch 47, Train Acc: 1.0000, Train Loss: 0.0026, Val Loss: 1.0079, Val Acc: 0.6172
# Epoch 48, Train Acc: 1.0000, Train Loss: 0.0026, Val Loss: 0.9985, Val Acc: 0.6172
# Epoch 49, Train Acc: 1.0000, Train Loss: 0.0026, Val Loss: 1.0082, Val Acc: 0.6406
# Epoch 50, Train Acc: 1.0000, Train Loss: 0.0023, Val Loss: 1.0089, Val Acc: 0.6172
# Epoch 51, Train Acc: 1.0000, Train Loss: 0.0023, Val Loss: 1.0013, Val Acc: 0.6328
# Epoch 52, Train Acc: 1.0000, Train Loss: 0.0021, Val Loss: 1.0060, Val Acc: 0.6406
# Epoch 53, Train Acc: 1.0000, Train Loss: 0.0025, Val Loss: 1.0016, Val Acc: 0.6328
# Epoch 54, Train Acc: 1.0000, Train Loss: 0.0022, Val Loss: 1.0113, Val Acc: 0.6250
# Epoch 55, Train Acc: 1.0000, Train Loss: 0.0021, Val Loss: 0.9989, Val Acc: 0.6250
# Epoch 56, Train Acc: 1.0000, Train Loss: 0.0020, Val Loss: 1.0078, Val Acc: 0.6094
# Epoch 57, Train Acc: 1.0000, Train Loss: 0.0020, Val Loss: 1.0162, Val Acc: 0.6250
# Epoch 58, Train Acc: 1.0000, Train Loss: 0.0019, Val Loss: 1.0107, Val Acc: 0.6250
# Epoch 59, Train Acc: 1.0000, Train Loss: 0.0018, Val Loss: 1.0101, Val Acc: 0.6406
# Epoch 60, Train Acc: 1.0000, Train Loss: 0.0018, Val Loss: 1.0133, Val Acc: 0.6328
# Epoch 61, Train Acc: 1.0000, Train Loss: 0.0017, Val Loss: 1.0018, Val Acc: 0.6484
# Epoch 62, Train Acc: 1.0000, Train Loss: 0.0016, Val Loss: 1.0172, Val Acc: 0.6406
# Epoch 63, Train Acc: 1.0000, Train Loss: 0.0016, Val Loss: 1.0098, Val Acc: 0.6250
# Epoch 64, Train Acc: 1.0000, Train Loss: 0.0017, Val Loss: 1.0146, Val Acc: 0.6172
# Epoch 65, Train Acc: 1.0000, Train Loss: 0.0016, Val Loss: 1.0217, Val Acc: 0.6328
# Epoch 66, Train Acc: 1.0000, Train Loss: 0.0017, Val Loss: 1.0153, Val Acc: 0.6328
# Epoch 67, Train Acc: 1.0000, Train Loss: 0.0015, Val Loss: 1.0178, Val Acc: 0.6172
# Epoch 68, Train Acc: 1.0000, Train Loss: 0.0015, Val Loss: 1.0058, Val Acc: 0.6250
# Epoch 69, Train Acc: 1.0000, Train Loss: 0.0014, Val Loss: 1.0163, Val Acc: 0.6328
# Epoch 70, Train Acc: 1.0000, Train Loss: 0.0015, Val Loss: 1.0184, Val Acc: 0.6172
# Epoch 71, Train Acc: 1.0000, Train Loss: 0.0014, Val Loss: 1.0124, Val Acc: 0.6250
# Epoch 72, Train Acc: 1.0000, Train Loss: 0.0013, Val Loss: 1.0205, Val Acc: 0.6406
# Epoch 73, Train Acc: 1.0000, Train Loss: 0.0013, Val Loss: 1.0288, Val Acc: 0.6328
# Epoch 74, Train Acc: 1.0000, Train Loss: 0.0013, Val Loss: 1.0308, Val Acc: 0.6328
# Epoch 75, Train Acc: 1.0000, Train Loss: 0.0013, Val Loss: 1.0171, Val Acc: 0.6406
# Epoch 76, Train Acc: 1.0000, Train Loss: 0.0014, Val Loss: 1.0375, Val Acc: 0.6328
# Epoch 77, Train Acc: 1.0000, Train Loss: 0.0012, Val Loss: 1.0345, Val Acc: 0.6328
# Epoch 78, Train Acc: 1.0000, Train Loss: 0.0012, Val Loss: 1.0411, Val Acc: 0.6328
# Epoch 79, Train Acc: 1.0000, Train Loss: 0.0013, Val Loss: 1.0319, Val Acc: 0.6328
# Epoch 80, Train Acc: 1.0000, Train Loss: 0.0013, Val Loss: 1.0548, Val Acc: 0.6094
# Epoch 81, Train Acc: 1.0000, Train Loss: 0.0012, Val Loss: 1.0410, Val Acc: 0.6328
# Epoch 82, Train Acc: 1.0000, Train Loss: 0.0011, Val Loss: 1.0412, Val Acc: 0.6406
# Epoch 83, Train Acc: 1.0000, Train Loss: 0.0011, Val Loss: 1.0384, Val Acc: 0.6250
# Epoch 84, Train Acc: 1.0000, Train Loss: 0.0011, Val Loss: 1.0412, Val Acc: 0.6328
# Epoch 85, Train Acc: 1.0000, Train Loss: 0.0011, Val Loss: 1.0403, Val Acc: 0.6406
# Epoch 86, Train Acc: 1.0000, Train Loss: 0.0011, Val Loss: 1.0446, Val Acc: 0.6172
# Epoch 87, Train Acc: 1.0000, Train Loss: 0.0011, Val Loss: 1.0437, Val Acc: 0.6484
# Epoch 88, Train Acc: 1.0000, Train Loss: 0.0010, Val Loss: 1.0484, Val Acc: 0.6328
# Epoch 89, Train Acc: 1.0000, Train Loss: 0.0011, Val Loss: 1.0369, Val Acc: 0.6484
# Epoch 90, Train Acc: 1.0000, Train Loss: 0.0010, Val Loss: 1.0464, Val Acc: 0.6484
# Epoch 91, Train Acc: 1.0000, Train Loss: 0.0010, Val Loss: 1.0534, Val Acc: 0.6250
# Epoch 92, Train Acc: 1.0000, Train Loss: 0.0010, Val Loss: 1.0495, Val Acc: 0.6250
# Epoch 93, Train Acc: 1.0000, Train Loss: 0.0010, Val Loss: 1.0498, Val Acc: 0.6406
# Epoch 94, Train Acc: 1.0000, Train Loss: 0.0009, Val Loss: 1.0512, Val Acc: 0.6250
# Epoch 95, Train Acc: 1.0000, Train Loss: 0.0009, Val Loss: 1.0520, Val Acc: 0.6328
# Epoch 96, Train Acc: 1.0000, Train Loss: 0.0009, Val Loss: 1.0469, Val Acc: 0.6328
# Epoch 97, Train Acc: 1.0000, Train Loss: 0.0009, Val Loss: 1.0455, Val Acc: 0.6328
# Epoch 98, Train Acc: 1.0000, Train Loss: 0.0009, Val Loss: 1.0445, Val Acc: 0.6250
# Epoch 99, Train Acc: 1.0000, Train Loss: 0.0009, Val Loss: 1.0470, Val Acc: 0.6328
# Epoch 100, Train Acc: 1.0000, Train Loss: 0.0008, Val Loss: 1.0523, Val Acc: 0.6406
# Done

# %%
torch.save(model.state_dict(),"final_model1.pth")

# %%
train_accuracy, training_losses, val_losses, val_accuracy = history1

# %%
len(train_accuracy), len(training_losses), len(val_losses), len(val_accuracy)
# Out:
# (100, 100, 100, 100)

# %%
# Plot Generator and Discriminator Loss
plt.plot(training_losses, '-')
plt.plot(val_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(["training_losses", "val_losses"])
plt.title('Model Losses')
# Out:
# Text(0.5, 1.0, 'Model Losses')

# %%
# Plot Real and Fake score
plt.plot(train_accuracy, '-')
plt.plot(val_accuracy, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Train Accuracy', "Val Accuracy"])
plt.title('Scores')
plt.show()
